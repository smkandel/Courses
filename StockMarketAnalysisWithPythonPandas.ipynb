# %% [markdown]
# <a href="https://colab.research.google.com/github/smkandel/Courses/blob/main/StockMarketAnalysisWithPythonPandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Stock Market Analysis With Python Pandas**

# %%
import pandas_datareader.data as web
import datetime
import matplotlib.pyplot as plt
import numpy as np
import yfinance as yf
# %matplotlib inline

# %%
from pandas_datareader import data as pdr

import yfinance as yf
yf.pdr_override() # <== that's all it takes :-)

# download dataframe
data = pdr.get_data_yahoo("SPY", start="2017-01-01", end="2017-04-30")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
start = datetime.datetime(2012,1,1)
end = datetime.datetime(2023,6,14)

# %%
# tesla = web.DataReader("yahoo",start,end)
# att = web.DataReader('F', 'yahoo', start, end)

google = yf.download('GOOGL', start=start, end= end)
tesla = yf.download('TSLA', start=start, end= end)
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
tesla
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2012-01-03    1.929333    1.966667    1.843333    1.872000    1.872000
# 2012-01-04    1.880667    1.911333    1.833333    1.847333    1.847333
# 2012-01-05    1.850667    1.862000    1.790000    1.808000    1.808000
# 2012-01-06    1.813333    1.852667    1.760667    1.794000    1.794000
# 2012-01-09    1.800000    1.832667    1.741333    1.816667    1.816667
# ...                ...         ...         ...         ...         ...
# 2023-06-07  228.000000  230.830002  223.199997  224.570007  224.570007
# 2023-06-08  224.220001  235.229996  223.009995  234.860001  234.860001
# 2023-06-09  249.070007  252.419998  242.020004  244.399994  244.399994
# 2023-06-12  247.940002  250.970001  244.589996  249.830002  249.830002
# 2023-06-13  253.509995  259.679993  251.339996  258.709991  258.709991
#
#                Volume
# Date
# 2012-01-03   13921500
# 2012-01-04    9451500
# 2012-01-05   15082500
# 2012-01-06   14794500
# 2012-01-09   13455000
# ...               ...
# 2023-06-07  185710800
# 2023-06-08  164489700
# 2023-06-09  199882300
# 2023-06-12  150337900
# 2023-06-13  162384300
#
# [2880 rows x 6 columns]

# %%
google
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2012-01-03   16.339840   16.720470   16.325577   16.651901   16.651901
# 2012-01-04   16.642391   16.773024   16.532032   16.723724   16.723724
# 2012-01-05   16.569820   16.615866   16.422173   16.491741   16.491741
# 2012-01-06   16.495245   16.516518   16.261011   16.266768   16.266768
# 2012-01-09   16.178679   16.191191   15.546296   15.577077   15.577077
# ...                ...         ...         ...         ...         ...
# 2023-06-07  126.970001  129.039993  122.120003  122.500000  122.500000
# 2023-06-08  122.230003  123.230003  121.239998  122.139999  122.139999
# 2023-06-09  122.250000  123.760002  121.910004  122.230003  122.230003
# 2023-06-12  122.790001  124.050003  121.660004  123.639999  123.639999
# 2023-06-13  124.980003  125.160004  123.180000  123.830002  123.830002
#
#                Volume
# Date
# 2012-01-03  146912940
# 2012-01-04  114445440
# 2012-01-05  131184684
# 2012-01-06  107608284
# 2012-01-09  232671096
# ...               ...
# 2023-06-07   52539000
# 2023-06-08   29389200
# 2023-06-09   23762500
# 2023-06-12   28306400
# 2023-06-13   22278300
#
# [2880 rows x 6 columns]

# %%
google['High-Low'] = google['High'] - google['Low']
google
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2012-01-03   16.339840   16.720470   16.325577   16.651901   16.651901
# 2012-01-04   16.642391   16.773024   16.532032   16.723724   16.723724
# 2012-01-05   16.569820   16.615866   16.422173   16.491741   16.491741
# 2012-01-06   16.495245   16.516518   16.261011   16.266768   16.266768
# 2012-01-09   16.178679   16.191191   15.546296   15.577077   15.577077
# ...                ...         ...         ...         ...         ...
# 2023-06-07  126.970001  129.039993  122.120003  122.500000  122.500000
# 2023-06-08  122.230003  123.230003  121.239998  122.139999  122.139999
# 2023-06-09  122.250000  123.760002  121.910004  122.230003  122.230003
# 2023-06-12  122.790001  124.050003  121.660004  123.639999  123.639999
# 2023-06-13  124.980003  125.160004  123.180000  123.830002  123.830002
#
#                Volume  High-Low
# Date
# 2012-01-03  146912940  0.394894
# 2012-01-04  114445440  0.240992
# 2012-01-05  131184684  0.193693
# 2012-01-06  107608284  0.255507
# 2012-01-09  232671096  0.644895
# ...               ...       ...
# 2023-06-07   52539000  6.919991
# 2023-06-08   29389200  1.990005
# 2023-06-09   23762500  1.849998
# 2023-06-12   28306400  2.389999
# 2023-06-13   22278300  1.980003
#
# [2880 rows x 7 columns]

# %%
google.head()
# Out:
#                  Open       High        Low      Close  Adj Close     Volume  \
# Date
# 2012-01-03  16.339840  16.720470  16.325577  16.651901  16.651901  146912940
# 2012-01-04  16.642391  16.773024  16.532032  16.723724  16.723724  114445440
# 2012-01-05  16.569820  16.615866  16.422173  16.491741  16.491741  131184684
# 2012-01-06  16.495245  16.516518  16.261011  16.266768  16.266768  107608284
# 2012-01-09  16.178679  16.191191  15.546296  15.577077  15.577077  232671096
#
#             High-Low
# Date
# 2012-01-03  0.394894
# 2012-01-04  0.240992
# 2012-01-05  0.193693
# 2012-01-06  0.255507
# 2012-01-09  0.644895

# %%
google['Open']
# Out:
# Date
# 2012-01-03     16.339840
# 2012-01-04     16.642391
# 2012-01-05     16.569820
# 2012-01-06     16.495245
# 2012-01-09     16.178679
#                  ...
# 2023-06-07    126.970001
# 2023-06-08    122.230003
# 2023-06-09    122.250000
# 2023-06-12    122.790001
# 2023-06-13    124.980003
# Name: Open, Length: 2880, dtype: float64

# %%
google['Open'].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
google['Open'].head().plot()
# Out:
# <Axes: xlabel='Date'>

# %%
google['Open'].plot(label="Google Opening Price")
google['Close'].plot(label="Google closing Price")
# Out:
# <Axes: xlabel='Date'>

# %%
google['Open'].head().plot(label="Google Opening Price")
google['Close'].head().plot(label="Google closing Price")
# Out:
# <Axes: xlabel='Date'>

# %%
google['Open'].head().plot(label="Google Opening Price")
google['Close'].head().plot(label="Google closing Price")
plt.legend()

# %%
google['Open'].head().plot(label="Google Opening Price")
google['Close'].head().plot(label="Google closing Price")
google['High'].head().plot(label="Google High Price")
google['Low'].head().plot(label="Google Low Price")
plt.legend()

# %%
google['Open'].head().plot(label="Google Opening Price")
google['Close'].head().plot(label="Google closing Price")
google['High'].head().plot(label="Google High Price")
google['Low'].head().plot(label="Google Low Price")
plt.title('Google Stock Price')
plt.xlabel('Stock Date')
plt.ylabel('Stock Volumn')
plt.legend()

# %%
google['Open'].plot(label="Google Opening Price")
google['Close'].plot(label="Google closing Price")
google['High'].plot(label="Google High Price")
google['Low'].plot(label="Google Low Price")
plt.title('Google Stock Price')
plt.xlabel('Stock Date')
plt.ylabel('Stock Volumn')
plt.legend()

# %%
google['Open'].plot(label="Google Opening Price", figsize=(20,10))
google['Close'].plot(label="Google closing Price")
google['High'].plot(label="Google High Price")
google['Low'].plot(label="Google Low Price")
plt.title('Google Stock Price')
plt.xlabel('Stock Date')
plt.ylabel('Stock Volumn')
plt.legend()

# %% [markdown]
# #**Stock Volume Traded Visualization**

# %%
google['Volume'].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
google['Volume'].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
from pandas_datareader import data as pdr

import yfinance as yf
yf.pdr_override() # <== that's all it takes :-)

# download dataframe
Tesla = pdr.get_data_yahoo("TSLA", start=start, end=end)
GM =  pdr.get_data_yahoo("GM", start=start, end=end)
Ford =  pdr.get_data_yahoo("F", start=start, end=end)
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %% [markdown]
# #**Tesla vs GM vs Ford**

# %%
tesla.to_csv('tesla_stock_price.csv')

# %%
Ford.to_csv('ford_stock_price.csv')

# %%
GM.to_csv('GM_stock_price.csv')

# %%
tesla.Open.plot()
Ford.Open.plot()
GM.Open.plot()
# Out:
# <Axes: xlabel='Date'>
