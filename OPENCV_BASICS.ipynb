# %% [markdown]
# <a href="https://colab.research.google.com/github/smkandel/Courses/blob/main/OPENCV_BASICS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# OPENCV READ IMAGES

# Python code to read image
import cv2
from google.colab.patches import cv2_imshow

# OPENCV ALWAYS USES NUMPY ARRAY TO READ IMAGES
img = cv2.imread("appleimage.jpg")
# height and width
print(img.shape)
cv2_imshow(img)
#cv2.imshow(nameofimage,image)
# Out:
# (194, 259, 3)
# <PIL.Image.Image image mode=RGB size=259x194 at 0x7F675E365A80>

# %% [markdown]
# Syntax: cv2.imread(path, flag)
#
# Parameters:
# path: A string representing the path of the image to be read.
# flag: It specifies the way in which image should be read. It’s default value is cv2.IMREAD_COLOR
#
# Return Value: This method returns an image that is loaded from the specified file.
#
# Note:
# The image should be in the working directory or a full path of image should be given.
# By default, OpenCV stores colored images in BGR(Blue Green and Red) format.

# %%
#import cv2, numpy and matplotlib libraries
import cv2
import numpy as np
import matplotlib.pyplot as plt

img=cv2.imread("appleimage.jpg")
# Converting BGR color to RGB color format

BGR_img = cv2.cvtColor(img, cv2.COLOR_RGB2BGR)
print(BGR_img.shape)
#Displaying image using plt.imshow() method
cv2_imshow(BGR_img)
# Out:
# (194, 259, 3)
# <PIL.Image.Image image mode=RGB size=259x194 at 0x7F675E365600>

# %%
RGB_img = cv2.cvtColor(BGR_img,cv2.COLOR_BGR2RGB)
cv2_imshow(RGB_img)
# Out:
# <PIL.Image.Image image mode=RGB size=259x194 at 0x7F672B6F9E40>

# %%
import cv2

img = cv2.imread("appleimage.jpg", cv2.IMREAD_GRAYSCALE)
print(img.shape)
cv2_imshow(img)
# Out:
# (194, 259)
# <PIL.Image.Image image mode=L size=259x194 at 0x7F672B6F9CF0>

# %%
import cv2

img = cv2.imread("appleimage.jpg")
img_bigger=cv2.resize(img, (780, 540))
print(img_bigger.shape)
cv2_imshow(img_bigger)
# Out:
# (540, 780, 3)
# <PIL.Image.Image image mode=RGB size=780x540 at 0x7F672B6F9B10>

# %%
import cv2

img = cv2.imread("appleimage.jpg")
start_point=(1,1)
end_point=(256,192)

# FORMAT IS BGR
color=(0,0,255)
thickness=2

image=cv2.rectangle(img,start_point,end_point,color,thickness)
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=259x194 at 0x7F672B6F9540>

# %%
import cv2

img = cv2.imread("appleimage.jpg")
image_flipped=cv2.flip(img,-1)
cv2_imshow(image_flipped)
# Out:
# <PIL.Image.Image image mode=RGB size=259x194 at 0x7F672B6FAAA0>

# %%
import cv2
img = cv2.imread("appleimage.jpg")
#cv2.ROTATE_90_COUNTERCLOCKWISE
#cv2.ROTATE_180
image_ROTATE=cv2.rotate(img,cv2.ROTATE_90_CLOCKWISE)
cv2_imshow(image_ROTATE)
# Out:
# <PIL.Image.Image image mode=RGB size=194x259 at 0x7F675F20BE80>

# %%
import cv2
img = cv2.imread("appleimage.jpg")
kernel_size=(3,3)
image_blur=cv2.blur(img,kernel_size)
cv2_imshow(image_blur)
# Out:
# <PIL.Image.Image image mode=RGB size=259x194 at 0x7F672B6FAFE0>

# %%
#draw line
img = cv2.imread("appleimage.jpg")
start_point=(0,0)
end_point=(192,192)

# FORMAT IS BGR
color=(0,0,255)
thickness=2

image=cv2.line(img,start_point,end_point,color,thickness)
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=259x194 at 0x7F675F090490>

# %%
#draw circle
img = cv2.imread("appleimage.jpg")
center_coordinates=(50,50)
radius=30

# FORMAT IS BGR
color=(0,0,255)
thickness=2

image= cv2.circle(image, center_coordinates, radius, color, thickness)
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=259x194 at 0x7F672B6FAA70>

# %%
#draw square
img = cv2.imread("appleimage.jpg")
start_point=(0,0)
end_point=(192,192)

# FORMAT IS BGR
color=(0,0,255)
thickness=2

image=cv2.rectangle(img,start_point,end_point,color,thickness)
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=259x194 at 0x7F672B6FA7A0>

# %%
img = cv2.imread("appleimage.jpg")
#window_name = 'Image'
text='Apples'
font = cv2.FONT_HERSHEY_SIMPLEX
org = (00, 185)
fontScale = 1
color = ( 255, 0, 0)
thickness = 2

image = cv2.putText(img, text, org, font,
                   fontScale, color, thickness, cv2.LINE_AA, False)
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=259x194 at 0x7F6729AB9CF0>
